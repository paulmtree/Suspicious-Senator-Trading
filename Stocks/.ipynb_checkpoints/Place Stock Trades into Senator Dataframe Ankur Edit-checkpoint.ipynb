# %% [markdown]
# # Place Stock Trades into Senator Dataframe

# %% [markdown]
# ## 1. Understand the Senator Trading Report (STR) Dataframe

# %%
import pandas as pd
#https://docs.google.com/spreadsheets/d/1lH_LpTgRlfzKvpRnWYgoxlkWvJj0v1r3zN3CeWMAgqI/edit?usp=sharing
try:
    sen_df = pd.read_csv("Senator Stock Trades/Senate Stock Watcher 04_16_2020 All Transactions.csv")
except:
    sen_df = pd.read_csv("https://github.com/pkm29/big_data_final_project/raw/master/Senate%20Stock%20Trades/Senate%20Stock%20Watcher%2004_16_2020%20All%20Transactions.csv")
sen_df.head()
# Out:
#   transaction_date  owner ticker  \
# 0       03/04/2020  Joint     --
# 1       03/04/2020   Self     --
# 2       03/11/2020   Self   ILMN
# 3       03/11/2020   Self   CGNX
# 4       03/11/2020   Self  SIEGY
#
#                                    asset_description asset_type         type  \
# 0  INGERSOLL RAND PLC SHARES (Exchanged) <br> TRA...      Stock     Exchange
# 1  INGERSOLL RAND PLC SHS (Exchanged) <br> TRANE ...      Stock     Exchange
# 2                                     Illumina, Inc.      Stock  Sale (Full)
# 3                                 Cognex Corporation      Stock  Sale (Full)
# 4                         Siemens Aktiengesellschaft      Stock  Sale (Full)
#
#               amount comment             senator  \
# 0   $1,001 - $15,000      --  Sheldon Whitehouse
# 1   $1,001 - $15,000      --  Sheldon Whitehouse
# 2   $1,001 - $15,000      --  Sheldon Whitehouse
# 3  $15,001 - $50,000      --  Sheldon Whitehouse
# 4  $15,001 - $50,000      --  Sheldon Whitehouse
#
#                                             ptr_link
# 0  https://efdsearch.senate.gov/search/view/ptr/4...
# 1  https://efdsearch.senate.gov/search/view/ptr/4...
# 2  https://efdsearch.senate.gov/search/view/ptr/4...
# 3  https://efdsearch.senate.gov/search/view/ptr/4...
# 4  https://efdsearch.senate.gov/search/view/ptr/4...

# %%
sen_df.type.unique()
# Out:
# array(['Exchange', 'Sale (Full)', 'Purchase', 'Sale (Partial)'],
#       dtype=object)

# %% [markdown]
# There are 4 types of trades.
# Exchanges: Exchange 1 stock for another
# Sale (Full): Selling all of their stock
# Purchase: Buying a stock
# Sale (Partial): Selling some of that particular stock

# %%
n_exchanges = len(sen_df.loc[sen_df['type'] == "Exchange"])
n_trades = len(sen_df)
print("There are " +str(n_exchanges) +" exchange trades out of a total of " +str(n_trades)+ " trades.")
sen_df = sen_df.loc[sen_df['type'] != "Exchange"]
# Out:
# There are 84 exchange trades out of a total of 8600 trades.

# %% [markdown]
# At this point in time, I will exclude exchange trades because they are so few and wish to build the basic structure of the project. As you can see, this would require splitting up the exchange into two rows with each company and so on. I may include this step later if time permits.

# %% [markdown]
# There should now be 8516 trades remaining in the dataframe. Let's make sure this is so.

# %%
n_trades = len(sen_df)
print("There are " +str(n_trades)+ " trades in the dataframe")
# Out:
# There are 8516 trades in the dataframe

# %%
n_blank_ticker = len(sen_df.loc[sen_df['ticker'] == "--"])
print("There are " +str(n_blank_ticker) +" trades w/o a ticker out of a total of " +str(n_trades)+ " trades")
sen_df = sen_df.loc[sen_df['ticker'] != "--"]
# Out:
# There are 1872 trades w/o a ticker out of a total of 8516 trades

# %% [markdown]
# For the same reasons we excluded exchange trades, we will also exclude trades without a ticker (which all public stocks have - the ticker is their identifier on the stock exchange). Eliminating trades without a ticker takes out trades of other types of securities (corporate bonds, municipal securities, non-public stock).

# %% [markdown]
# There should now be 6644 trades remaining in the dataframe. Let's make sure this is so.

# %%
n_trades = len(sen_df)
print("There are " +str(n_trades)+ " trades in the dataframe")
# Out:
# There are 6644 trades in the dataframe

# %% [markdown]
# ## 2. Add Data to STR Dataframe

# %% [markdown]
# ### Import Data

# %% [markdown]
# In this step we will be using company information such as market cap and industry from online lists provided by the NYSE, NASDAQ, and ASXL exchange. Links can be found here:https://stackoverflow.com/questions/25338608/download-all-stock-symbol-list-of-a-market

# %%
ticker_list = list()
try:
    NYSE_df = pd.read_csv("NYSEcompanylist.csv")
except:
    NYSE_df = pd.read_csv("https://github.com/pkm29/big_data_final_project/raw/master/Stocks/NYSEcompanylist.csv")
    
try:
    NASDAQ_df = pd.read_csv("NASDAQcompanylist.csv")
except:
    NASDAQ_df = pd.read_csv("https://github.com/pkm29/big_data_final_project/raw/master/Stocks/NASDAQcompanylist.csv")
    
#try:
#    ASXL_df = pd.read_csv("ASXLcompanylist.csv")
#except:
#    ASXL_df = pd.read_csv("https://github.com/pkm29/big_data_final_project/raw/master/Stocks/ASXLcompanylist.csv")
    
ticker_list.append(NYSE_df)
ticker_list.append(NASDAQ_df)
#ticker_list.append(ASXL_df)


#ticker_list[0].head()

# %%
#Get sector data for each stock trade

sector_data = list()
for row_tuple in sen_df.itertuples():
    tic = row_tuple.ticker
    count = 0
    for row_tuple_tic in ticker_list[0].itertuples():
        sym = row_tuple_tic.Symbol
        if tic == sym:
            count = count+1
            if row_tuple_tic.Sector == "n/a":
                sector_data.append("none")
            else:
                sector_data.append(row_tuple_tic.Sector)
            break
    if count == 0:
        for row_tuple_tic in ticker_list[1].itertuples():
            sym = row_tuple_tic.Symbol
            if tic == sym:
                count = count+1
                if row_tuple_tic.Sector == "n/a":
                    sector_data.append("none")
                else:
                    sector_data.append(row_tuple_tic.Sector)
                break
    if count == 0:
        sector_data.append("none")
        
print(sector_data[0:9])
# Out:
# ['Capital Goods', 'none', 'none', 'Basic Industries', 'Consumer Services', 'Finance', 'Technology', 'Health Care', 'Consumer Services']

# %%
#make sure length matches number of rows in df
print(len(sector_data))

#counter for how many times the stock traded by senator not found in exchange data set
no_ticker_cnt = 0
#counter for how many times stock was found in exch data set, but that company's data had no a value for the field
ticker_missing_field_cnt = 0

for i in sector_data:
    if i == "none":
        no_ticker_cnt = no_ticker_cnt + 1
        
    if i == "n/a":
        ticker_missing_field_cnt = ticker_missing_field_cnt + 1
    
print(no_ticker_cnt)
print(ticker_missing_field_cnt)
# Out:
# 6644
# 1206
# 0

# %%
#Get industry data for each stock trade

industry_data = list()
for row_tuple in sen_df.itertuples():
    tic = row_tuple.ticker
    count = 0
    for row_tuple_tic in ticker_list[0].itertuples():
        sym = row_tuple_tic.Symbol
        if tic == sym:
            count = count+1
            if row_tuple_tic.industry == "n/a":
                industry_data.append("none")
            else:
                industry_data.append(row_tuple_tic.industry)
            break
    if count == 0:
        for row_tuple_tic in ticker_list[1].itertuples():
            sym = row_tuple_tic.Symbol
            if tic == sym:
                count = count+1
                if row_tuple_tic.industry == "n/a":
                    industry_data.append("none")
                else:
                    industry_data.append(row_tuple_tic.industry)
                break
    if count == 0:
        industry_data.append("none")
        
print(industry_data[0:9])
# Out:
# ['Biotechnology: Laboratory Analytical Instruments', 'Industrial Machinery/Components', 'none', 'none', 'Paints/Coatings', 'Building operators', 'Major Banks', 'Semiconductors', 'Major Pharmaceuticals', 'Newspapers/Magazines', 'Oil & Gas Production', 'Food Chains', 'Major Chemicals', 'Hotels/Resorts', 'Hotels/Resorts', 'Major Banks', 'Food Chains', 'Food Chains', 'Major Banks', 'Food Chains', 'Clothing/Shoe/Accessory Stores', 'Clothing/Shoe/Accessory Stores', 'Clothing/Shoe/Accessory Stores', 'Auto Manufacturing', 'Food Chains', 'Clothing/Shoe/Accessory Stores', 'Food Chains', 'none', 'none', 'Clothing/Shoe/Accessory Stores', 'none', 'Major Banks', 'none', 'none', 'Industrial Machinery/Components', 'Department/Specialty Retail Stores', 'Newspapers/Magazines', 'Broadcasting', 'Industrial Machinery/Components', 'Oil Refining/Marketing', 'Natural Gas Distribution', 'Food Chains', 'Food Chains', 'Natural Gas Distribution', 'Natural Gas Distribution', 'Food Chains', 'Natural Gas Distribution', 'Food Chains', 'Paints/Coatings', 'Food Chains', 'Food Chains', 'Food Chains', 'Major Banks', 'Broadcasting', 'Services-Misc. Amusement & Recreation', 'Major Chemicals', 'Rental/Leasing Companies', 'Services-Misc. Amusement & Recreation', 'Paints/Coatings', 'Package Goods/Cosmetics', 'Beverages (Production/Distribution)', 'Newspapers/Magazines', 'Major Banks', 'EDP Services', 'Food Distributors', 'Industrial Machinery/Components', 'Food Chains', 'Major Banks', 'Major Chemicals', 'Auto Manufacturing', 'Services-Misc. Amusement & Recreation', 'Food Chains', 'Food Chains', 'Major Banks', 'Food Chains', 'Rental/Leasing Companies', 'Computer Software: Programming, Data Processing', 'Computer Software: Programming, Data Processing', 'Services-Misc. Amusement & Recreation', 'Restaurants', 'Food Chains', 'Computer Software: Programming, Data Processing', 'Food Chains', 'Specialty Chemicals', 'none', 'Food Distributors', 'Natural Gas Distribution', 'Industrial Machinery/Components', 'Newspapers/Magazines', 'Natural Gas Distribution', 'Food Chains', 'Department/Specialty Retail Stores', 'Major Banks', 'none', 'Restaurants', 'Major Banks', 'Restaurants', 'Apparel', 'Restaurants', 'none', 'none', 'Major Chemicals', 'Consumer Electronics/Video Chains', 'Natural Gas Distribution', 'none', 'Natural Gas Distribution', 'none', 'Computer Software: Prepackaged Software', 'none', 'none', 'Semiconductors', 'Containers/Packaging', 'Restaurants', 'Semiconductors', 'Containers/Packaging', 'Semiconductors', 'Semiconductors', 'Telecommunications Equipment', 'none', 'none', 'Services-Misc. Amusement & Recreation', 'Semiconductors', 'Medical/Nursing Services', 'Business Services', 'Telecommunications Equipment', 'Integrated oil Companies', 'Major Banks', 'Computer Communications Equipment', 'Major Pharmaceuticals', 'Major Banks', 'Major Chemicals', 'Packaged Foods', 'Business Services', 'Property-Casualty Insurers', 'Major Pharmaceuticals', 'Computer Software: Prepackaged Software', 'Life Insurance', 'Integrated oil Companies', 'Major Chemicals', 'Property-Casualty Insurers', 'Consumer Electronics/Appliances', 'Metal Fabrications', 'Property-Casualty Insurers', 'Biotechnology: Biological Products (No Diagnostic Substances)', 'Property-Casualty Insurers', 'Computer peripheral equipment', 'Integrated oil Companies', 'Integrated oil Companies', 'Major Chemicals', 'Major Chemicals', 'Major Chemicals', 'Transportation Services', 'Transportation Services', 'Home Furnishings', 'Transportation Services', 'Clothing/Shoe/Accessory Stores', 'Clothing/Shoe/Accessory Stores', 'Apparel', 'Computer Software: Programming, Data Processing', 'Clothing/Shoe/Accessory Stores', 'Investment Bankers/Brokers/Service', 'Semiconductors', 'Other Specialty Stores', 'EDP Services', 'Major Pharmaceuticals', 'Catalog/Specialty Distribution', 'Investment Bankers/Brokers/Service', 'Catalog/Specialty Distribution', 'Semiconductors', 'Semiconductors', 'Computer Software: Programming, Data Processing', 'M ...

# %%
#make sure length matches number of rows in df
print(len(industry_data))

#counter for how many times the stock traded by senator not found in exchange data set
no_ticker_cnt = 0
#counter for how many times stock was found in exch data set, but that company's data had no a value for the field
ticker_missing_field_cnt = 0

for i in industry_data:
    if i == "none":
        no_ticker_cnt = no_ticker_cnt + 1
        
    if i == "n/a":
        ticker_missing_field_cnt = ticker_missing_field_cnt + 1
    
print(no_ticker_cnt)
print(ticker_missing_field_cnt)
# Out:
# 6644
# 1206
# 0

# %%
#Get market cap data for each stock trade

mktcap_data = list()
for row_tuple in sen_df.itertuples():
    tic = row_tuple.ticker
    count = 0
    for row_tuple_tic in ticker_list[0].itertuples():
        sym = row_tuple_tic.Symbol
        if tic == sym:
            count = count+1
            if row_tuple_tic.MarketCap == "n/a":
                mktcap_data.append("none")
            else:
                mktcap_data.append(row_tuple_tic.MarketCap)
            break
    if count == 0:
        for row_tuple_tic in ticker_list[1].itertuples():
            sym = row_tuple_tic.Symbol
            if tic == sym:
                count = count+1
                if row_tuple_tic.MarketCap == "n/a":
                    mktcap_data.append("none")
                else:
                    mktcap_data.append(row_tuple_tic.MarketCap)
                break
    if count == 0:
        mktcap_data.append("none")
        
print(mktcap_data[0:9])
# Out:
# ['$47.15B', '$8.58B', 'none', 'none', '$8.74B', '$34.86B', '$92.93B', '$52.6B', '$190.9B', '$7.75B', '$3.32B', '$25.42B', '$32.84B', '$8.88B', '$8.88B', '$198.15B', '$25.42B', '$25.42B', '$198.15B', '$25.42B', '$2.51B', '$2.51B', '$2.51B', '$32.58B', '$25.42B', '$2.51B', '$25.42B', 'none', 'none', '$2.51B', 'none', '$198.15B', 'none', 'none', '$3.26B', '$1.57B', '$7.57B', '$22.2B', '$1.81B', '$731.8M', '$64.54B', '$25.42B', '$25.42B', '$43.07B', '$64.54B', '$25.42B', '$43.07B', '$25.42B', '$4.48B', '$25.42B', '$25.42B', '$25.42B', '$9.43B', '$21.71B', '$8.47B', '$3.29B', '$7.1B', '$8.47B', '$4.48B', '$277.69B', '$189.41B', '$7.57B', '$3.74B', '$35.1B', '$26.58B', '$3.26B', '$25.42B', '$103.35B', '$3.29B', '$32.58B', '$8.47B', '$25.42B', '$25.42B', '$198.15B', '$25.42B', '$7.1B', '$1.44B', '$1.44B', '$8.47B', '$101.2B', '$25.42B', '$900.01B', '$25.42B', '$25.44B', 'none', '$26.58B', '$1.55B', '$3.26B', '$7.57B', '$1.55B', '$25.42B', '$1.57B', '$198.15B', 'none', '$101.2B', '$198.15B', '$101.2B', '$5.18B', '$101.2B', 'none', 'none', '$24.33B', '$137.9B', '$43.07B', 'none', '$23.31B', 'none', '$165.88B', 'none', 'none', '$52.6B', '$3.6B', '$101.2B', '$52.6B', '$3.6B', '$52.6B', '$52.6B', '$229.99B', 'none', 'none', '$190.6B', '$16.88B', '$80.23B', '$126.82B', '$53.06B', '$20.01B', '$103.35B', '$192.29B', '$124.37B', '$277.87B', '$32.84B', '$21.48B', '$527.13B', '$5.89B', '$124.37B', '$12.53B', '$22.46B', '$172.96B', '$32.84B', '$5.89B', '$33.02B', '$2.97B', '$12.5B', '$139.47B', '$21.98B', '$21.25B', '$172.96B', '$81.24B', '$32.84B', '$32.84B', '$32.84B', '$79.69B', '$79.69B', '$4.06B', '$79.69B', '$58.09B', '$42.01B', '$29.4B', '$575.03B', '$42.01B', '$72.65B', '$131.99B', '$23.64B', '$73.9B', '$2.37B', '$892.83B', '$72.65B', '$892.83B', '$131.99B', '$4.71B', '$575.03B', '$2.37B', '$50.94B', '$50.94B', '$50.94B', '$50.94B', '$50.94B', '$42.98B', '$39.97B', '$1154.85B', '$1154.85B', '$190.6B', '$187.15B', '$172.96B', '$72.6B', '$345.4B', '$1187.46B', '$389.01B', '$345.4B', '$137.9B', '$131.99B', '$137.9B', '$1187.46B', '$137.9B', '$131.99B', '$1187.46B', '$1187.46B', '$137.9B', '$345.4B', '$28.87B', '$277.69B', '$1154.85B', '$132.6B', '$33.02B', '$77.14B', '$1187.46B', '$139.47B', '$205.84B', '$22.61B', '$32.01B', '$83.83B', '$389.1B', '$24.33B', 'none', '$8.78B', '$187.15B', 'none', '$34.86B', '$200.85B', '$192.29B', '$62.7B', '$172.96B', '$132.28B', '$22.46B', '$58.09B', '$42.01B', '$23.64B', '$23.64B', '$42.01B', '$18.18B', '$200.85B', '$648.95M', '$648.95M', '$12.4B', '$648.95M', '$165.88B', '$187.15B', '$14.69B', '$705.19M', '$8.49B', '$33.46B', '$705.19M', '$705.19M', '$23.64B', '$2.37B', 'none', '$18.94B', '$705.19M', '$2.37B', 'none', '$11.94B', '$200.85B', '$23.64B', '$93.2B', '$190.9B', '$12.4B', '$13.83B', '$33.02B', '$58.07B', '$25.74B', '$103.35B', '$345.4B', '$131.99B', '$1154.85B', '$405.76M', '$405.76M', '$1.59B', '$1.59B', '$32.58B', '$205.04B', '$32.84B', '$32.84B', '$4.6B', '$205.04B', '$205.04B', '$8.88B', '$8.88B', '$32.84B', '$205.04B', '$32.84B', '$13.83B', '$205.04B', '$32.84B', '$8.88B', '$8.88B', '$8.88B', '$205.04B', '$205.04B', '$8.88B', '$3.6B', '$8.88B', '$32.84B', '$205.04B', '$32.84B', '$205.84B', 'none', '$205.84B', '$190.6B', '$8.88B', '$3.63B', '$3.6B', '$13.83B', '$205.84B', 'none', '$4.6B', '$205.84B', '$205.84B', '$8.88B', '$205.84B', 'none', '$205.84B', '$8.88B', 'none', '$43.07B', '$205.84B', '$8.88B', '$13.83B', '$205.84B', '$43.07B', '$3.24B', '$3.24B', '$23.31B', '$3.13B', '$3.13B', '$3.24B', '$20.15B', '$20.15B', '$1187.46B', '$20.15B', '$20.15B', '$23.31B', '$23.31B', '$3.13B', '$17.55B', '$64.54B', '$1.59B', '$1.59B', 'none', '$6.35B', '$3.05B', '$3.05B', '$4.72B', '$12.31B', '$205.84B', '$9.36B', '$9.36B', '$9.36B', 'none', '$205.84B', '$2.08B', '$126.82B', '$67.33B', '$113.93B', '$34.86B', '$1187.46B', '$200.85B', '$192.29B', '$62.7B', '$172.96B', '$132.28B', '$22.46B', '$58.09B', '$42.01B', '$23.64B', '$23.64B', '$42.01B', '$18.18B', '$200.85B', '$648.95M', '$648.95M', '$12.4B', '$ ...

# %%
#make sure length matches number of rows in df
print(len(mktcap_data))

#counter for how many times the stock traded by senator not found in exchange data set
no_ticker_cnt = 0
#counter for how many times stock was found in exch data set, but that company's data had no a value for the field
ticker_missing_field_cnt = 0

for i in mktcap_data:
    if i == "none":
        no_ticker_cnt = no_ticker_cnt + 1
        
    if i == "n/a":
        ticker_missing_field_cnt = ticker_missing_field_cnt + 1
        
print(no_ticker_cnt)
print(ticker_missing_field_cnt)
# Out:
# 6644
# 1206
# 0

# %%
#add new columns to df

sen_df['mkt_cap'] = mktcap_data
sen_df['sector'] = sector_data
sen_df['industry'] = industry_data

sen_df = sen_df.fillna("none")
sen_df.head()
# Out:
#   transaction_date  owner ticker  \
# 2       03/11/2020   Self   ILMN
# 3       03/11/2020   Self   CGNX
# 4       03/11/2020   Self  SIEGY
# 5       02/27/2020  Joint  WCMIX
# 6       02/27/2020  Joint    RPM
#
#                                    asset_description        asset_type  \
# 2                                     Illumina, Inc.             Stock
# 3                                 Cognex Corporation             Stock
# 4                         Siemens Aktiengesellschaft             Stock
# 5  WCM Focused International Growth Fund Institut...  Other Securities
# 6                             RPM International Inc.             Stock
#
#              type              amount  \
# 2     Sale (Full)    $1,001 - $15,000
# 3     Sale (Full)   $15,001 - $50,000
# 4     Sale (Full)   $15,001 - $50,000
# 5        Purchase  $50,001 - $100,000
# 6  Sale (Partial)  $50,001 - $100,000
#
#                                              comment             senator  \
# 2                                                 --  Sheldon Whitehouse
# 3                                                 --  Sheldon Whitehouse
# 4                                                 --  Sheldon Whitehouse
# 5  The filer's portfolio is managed by a third pa...   Daniel S Sullivan
# 6  The filer's portfolio is managed by a third pa...   Daniel S Sullivan
#
#                                             ptr_link  mkt_cap  \
# 2  https://efdsearch.senate.gov/search/view/ptr/4...  $47.15B
# 3  https://efdsearch.senate.gov/search/view/ptr/4...   $8.58B
# 4  https://efdsearch.senate.gov/search/view/ptr/4...     none
# 5  https://efdsearch.senate.gov/search/view/ptr/e...     none
# 6  https://efdsearch.senate.gov/search/view/ptr/e...   $8.74B
#
#              sector                                          industry
# 2     Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 3     Capital Goods                   Industrial Machinery/Components
# 4              none                                              none
# 5              none                                              none
# 6  Basic Industries                                   Paints/Coatings

# %%
"""
Print out names of companies with missing data to find out why we have so many misses (around 18% of our data).
From quick insights, seem to be 3 reasons for this:
1. Mismatched tickers (e.g. berkshire class b ticker is BRK.B as in exch data but denoted BRK-B in senate data)
2. Foreign companies (listed abroad)
3. American companies listed abroad
"""

company_missing_data = list()
for row_tuple in sen_df.itertuples():
    if row_tuple.mkt_cap == "none":
        company_missing_data.append(row_tuple.asset_description)

print(company_missing_data[0:9])
# Out:
# ['Siemens Aktiengesellschaft', 'WCM Focused International Growth Fund Institutiona', 'Berkshire Hathaway Inc.', 'Berkshire Hathaway Inc.', 'Berkshire Hathaway Inc.', 'Berkshire Hathaway Inc.', 'Berkshire Hathaway Inc.', 'Bollore', 'Bollore', 'Bollore', 'Bollore', 'Bollore', 'Cheniere Energy, Inc.', 'Bollore', 'ViacomCBS Inc.', 'SPDR S&amp;P 500 ETF Trust', 'Sprott Physical Gold and Silver Trust', 'Vanguard FTSE Emerging Markets Index Fund ETF Shar', 'Berkshire Hathaway Inc.', 'Tencent Holdings Limited', 'Tencent Holdings Limited', 'ViacomCBS Inc.', 'ViacomCBS Inc.', 'ViacomCBS Inc.', 'ViacomCBS Inc.', 'Cheniere Energy, Inc.', 'ViacomCBS Inc.', 'Cheniere Energy, Inc.', 'Vanguard Intermediate-Term Bond Index Fund ETF Sha', 'Vanguard GNMA Fund Admiral Shares', 'Templeton Global Bond Fund Advisor Class', 'iShares Edge MSCI USA Momentum Factor ETF', 'SPDR S&amp;P 500 ETF', 'CBS Corporation', 'Lions Gate Entertainment Corp.', 'Bollore', 'CBS Corporation', 'SPDR S&amp;P 500 ETF', 'CBS Corporation', 'Lions Gate Entertainment Corp.', 'CBS Corporation', 'SPDR S&amp;P 500 ETF', 'Lions Gate Entertainment Corp.', 'Lions Gate Entertainment Corp.', 'Bollore', 'Bollore', 'Bollore', 'Bollore', 'Raytheon Company', 'BB&amp;T Corporation <div class="text-muted"><em>Rate/Coupon:</em> 5.25%<br> <em>Matures:</em> 11/01/2019</div>', 'BB&amp;T Corporation <div class="text-muted"><em>Rate/Coupon:</em> 5.25<br> <em>Matures:</em> 11/01/2019</div>', 'Bollore', 'CBS Corporation', 'CBS Corporation', 'SPDR S&amp;P 500 ETF', 'CBS Corporation', 'SPDR S&amp;P 500 ETF', 'Lions Gate Entertainment Corp.', 'Celgene Corporation', 'VISA - CLASSE A', 'SPDR Bloomberg Barclays High Yield Bond ETF', 'FACEBOOK INC FACEBOOK CLASS A', 'VISA - CLASSE A', 'SPDR Bloomberg Barclays High Yield Bond ETF', 'FACEBOOK INC FACEBOOK CLASS A', 'Berkshire Hathaway Inc.', 'SPDR S&amp;P Biotech ETF', 'Buckeye Partners, L.P.', 'Buckeye Partners, L.P.', 'Buckeye Partners, L.P.', 'Buckeye Partners, L.P.', 'Buckeye Partners, L.P.', 'Buckeye Partners, L.P.', 'BB&amp;T Corporation <div class="text-muted"><em>Rate/Coupon:</em> 5.25%<br> <em>Matures:</em> 11/01/2019</div>', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'Revere Bank', 'BlackRock Global Allocation Fund, Inc. Institution', 'Glenmede Small Cap Equity Portfolio Class Advisor', 'AMG TimesSquare Small Cap Growth Fund Class Z', 'Vanguard PRIMECAP Fund Admiral Shares', 'iShares Russell 1000 Growth ETF', 'Revere Bank', 'Sprott Physical Gold and Silver Trust', 'Lions Gate Entertainment Corp.', 'Nestl\\u00e9 S.A.', 'Royal Dutch Shell plc', 'Cheniere Energy, Inc.', 'Lions Gate Entertainment Corp.', 'Red Hat, Inc.', 'Avon Products, Inc.', 'Liberty Media Corp. Reg.Sh.C FO', 'Royal Dutch Shell plc', 'Liberty Media Corp. Reg.Sh.C FO', 'Berkshire Hathaway Inc.', 'Royal Dutch Shell plc', 'Liberty Media Corp. Reg.Sh.C FO', 'Royal Dutch Shell plc', 'Liberty Media Corp. Reg.Sh.C FO', 'Berkshire Hathaway Inc.', 'Celgene Corporation', 'United Technologies Corporation', 'Praxair, Inc.', 'Harris Corporation', 'Vanguard FTSE Europe ETF', 'Nestl\\u00e9 S.A.', 'iShares US Energy ETF', 'Roche Holding AG', 'Berkshire Hathaway Inc.', 'United Technologies Corporation', 'Praxair, Inc.', 'Harris Corporation', 'Royal Dutch Shell plc', 'Fanuc Corporation', 'DowDuPont Inc.', 'Royal Dutch Shell plc', 'Fanuc Corporation', 'DowDuPont Inc.', 'Anadarko Petroleum Corporation', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Weight Watchers International, Inc.', 'Siemens Aktiengesellschaft', 'First Data Corporation', 'First Data Corporation', 'First Data Corporation', 'First Data Corporation', 'First Data Corporation', 'First Data Corporation', 'CBS  ...

# %%
#Get a view of how many industries are found in our senate stock data.

from collections import Counter
industry_dict = Counter(industry_data)

industry_list = list()
for x in industry_dict:
    industry_list.append(x)
    
print(industry_list[0:9])
n_industries = len(industry_list)
#since 'none' is included in our list
n_industries = n_industries - 1
print("There are " + str(n_industries) + " industries covered by the trades of senators.")
# Out:
# ['Biotechnology: Laboratory Analytical Instruments', 'Industrial Machinery/Components', 'none', 'Paints/Coatings', 'Building operators', 'Major Banks', 'Semiconductors', 'Major Pharmaceuticals', 'Newspapers/Magazines', 'Oil & Gas Production', 'Food Chains', 'Major Chemicals', 'Hotels/Resorts', 'Clothing/Shoe/Accessory Stores', 'Auto Manufacturing', 'Department/Specialty Retail Stores', 'Broadcasting', 'Oil Refining/Marketing', 'Natural Gas Distribution', 'Services-Misc. Amusement & Recreation', 'Rental/Leasing Companies', 'Package Goods/Cosmetics', 'Beverages (Production/Distribution)', 'EDP Services', 'Food Distributors', 'Computer Software: Programming, Data Processing', 'Restaurants', 'Specialty Chemicals', 'Apparel', 'Consumer Electronics/Video Chains', 'Computer Software: Prepackaged Software', 'Containers/Packaging', 'Telecommunications Equipment', 'Medical/Nursing Services', 'Business Services', 'Integrated oil Companies', 'Computer Communications Equipment', 'Packaged Foods', 'Property-Casualty Insurers', 'Life Insurance', 'Consumer Electronics/Appliances', 'Metal Fabrications', 'Biotechnology: Biological Products (No Diagnostic Substances)', 'Computer peripheral equipment', 'Transportation Services', 'Home Furnishings', 'Investment Bankers/Brokers/Service', 'Other Specialty Stores', 'Catalog/Specialty Distribution', 'Environmental Services', 'Real Estate Investment Trusts', 'Aerospace', 'Computer Manufacturing', 'Biotechnology: Electromedical & Electrotherapeutic Apparatus', 'Medical/Dental Instruments', 'Oilfield Services/Equipment', 'Television Services', 'Wholesale Distributors', 'Finance: Consumer Services', 'Recreational Products/Toys', 'Precious Metals', 'Air Freight/Delivery Services', 'Construction/Ag Equipment/Trucks', 'Accident &Health Insurance', nan, 'Plastic Products', 'Other Consumer Services', 'Professional Services', 'Paper', 'Auto Parts:O.E.M.', 'Electric Utilities: Central', 'Farming/Seeds/Milling', 'Investment Managers', 'Power Generation', 'Medical Specialities', 'Agricultural Chemicals', 'Trucking Freight/Courier Services', 'Savings Institutions', 'Electrical Products', 'Railroads', 'Mining & Quarrying of Nonmetallic Minerals (No Fuels)', 'RETAIL: Building Materials', 'Industrial Specialties', 'Misc Health and Biotechnology Services', 'Military/Government/Technical', 'Radio And Television Broadcasting And Communications Equipment', 'Diversified Commercial Services', 'Shoe Manufacturing', 'Marine Transportation', 'Office Equipment/Supplies/Services', 'Electronic Components', 'Biotechnology: Commercial Physical & Biological Resarch', 'Medical Electronics', 'Automotive Aftermarket', 'Specialty Insurers', 'Biotechnology: In Vitro & In Vivo Diagnostic Substances', 'Coal Mining', 'Commercial Banks', 'Building Products', 'Other Pharmaceuticals', 'Textiles', 'Meat/Poultry/Fish', 'Ordnance And Accessories', 'Homebuilding', 'Specialty Foods', 'Electronics Distribution', 'Water Supply', 'Engineering & Construction', 'Steel/Iron Ore', 'Oil/Gas Transmission', 'Tools/Hardware', 'Advertising', 'Hospital/Nursing Management', 'Fluid Controls']
# There are 113 industries covered by the trades of senators.

# %%
import string

industry_size_data = list()

for row_tuple in sen_df.itertuples():
    industry_size = row_tuple.industry
    
    if industry_size == 'none':
        industry_size_data.append("none")
        continue
    
    size = row_tuple.mkt_cap
    factor = 0
    x = size.find("M")
    if x != -1:
        factor = 1000000
    else:
        factor = 1000000000
    
    size = size.lstrip("$")
    size = size.rstrip("MB")
    size = float(size)
    size = size*factor
    
    if size < 500000000:
        industry_size = industry_size + "1"
        industry_size_data.append(industry_size)
        continue
    elif size < 1000000000:
        industry_size = industry_size + "2"
        industry_size_data.append(industry_size)
        continue
    elif size < 10000000000:
        industry_size = industry_size + "3"
        industry_size_data.append(industry_size)
        continue
    elif size < 50000000000:
        industry_size = industry_size + "4"
        industry_size_data.append(industry_size)
        continue
    elif size < 100000000000:
        industry_size = industry_size + "5"
        industry_size_data.append(industry_size)
        continue
    elif size < 500000000000:
        industry_size = industry_size + "6"
        industry_size_data.append(industry_size)
        continue
    else:
        industry_size = industry_size + "7"
        industry_size_data.append(industry_size)
        continue
    
print(industry_size_data[0:9])
#print(len(industry_size_data))
# Out:
# ['Biotechnology: Laboratory Analytical Instruments4', 'Industrial Machinery/Components3', 'none', 'none', 'Paints/Coatings3', 'Building operators4', 'Major Banks5', 'Semiconductors5', 'Major Pharmaceuticals6', 'Newspapers/Magazines3', 'Oil & Gas Production3', 'Food Chains4', 'Major Chemicals4', 'Hotels/Resorts3', 'Hotels/Resorts3', 'Major Banks6', 'Food Chains4', 'Food Chains4', 'Major Banks6', 'Food Chains4', 'Clothing/Shoe/Accessory Stores3', 'Clothing/Shoe/Accessory Stores3', 'Clothing/Shoe/Accessory Stores3', 'Auto Manufacturing4', 'Food Chains4', 'Clothing/Shoe/Accessory Stores3', 'Food Chains4', 'none', 'none', 'Clothing/Shoe/Accessory Stores3', 'none', 'Major Banks6', 'none', 'none', 'Industrial Machinery/Components3', 'Department/Specialty Retail Stores3', 'Newspapers/Magazines3', 'Broadcasting4', 'Industrial Machinery/Components3', 'Oil Refining/Marketing2', 'Natural Gas Distribution5', 'Food Chains4', 'Food Chains4', 'Natural Gas Distribution4', 'Natural Gas Distribution5', 'Food Chains4', 'Natural Gas Distribution4', 'Food Chains4', 'Paints/Coatings3', 'Food Chains4', 'Food Chains4', 'Food Chains4', 'Major Banks3', 'Broadcasting4', 'Services-Misc. Amusement & Recreation3', 'Major Chemicals3', 'Rental/Leasing Companies3', 'Services-Misc. Amusement & Recreation3', 'Paints/Coatings3', 'Package Goods/Cosmetics6', 'Beverages (Production/Distribution)6', 'Newspapers/Magazines3', 'Major Banks3', 'EDP Services4', 'Food Distributors4', 'Industrial Machinery/Components3', 'Food Chains4', 'Major Banks6', 'Major Chemicals3', 'Auto Manufacturing4', 'Services-Misc. Amusement & Recreation3', 'Food Chains4', 'Food Chains4', 'Major Banks6', 'Food Chains4', 'Rental/Leasing Companies3', 'Computer Software: Programming, Data Processing3', 'Computer Software: Programming, Data Processing3', 'Services-Misc. Amusement & Recreation3', 'Restaurants6', 'Food Chains4', 'Computer Software: Programming, Data Processing7', 'Food Chains4', 'Specialty Chemicals4', 'none', 'Food Distributors4', 'Natural Gas Distribution3', 'Industrial Machinery/Components3', 'Newspapers/Magazines3', 'Natural Gas Distribution3', 'Food Chains4', 'Department/Specialty Retail Stores3', 'Major Banks6', 'none', 'Restaurants6', 'Major Banks6', 'Restaurants6', 'Apparel3', 'Restaurants6', 'none', 'none', 'Major Chemicals4', 'Consumer Electronics/Video Chains6', 'Natural Gas Distribution4', 'none', 'Natural Gas Distribution4', 'none', 'Computer Software: Prepackaged Software6', 'none', 'none', 'Semiconductors5', 'Containers/Packaging3', 'Restaurants6', 'Semiconductors5', 'Containers/Packaging3', 'Semiconductors5', 'Semiconductors5', 'Telecommunications Equipment6', 'none', 'none', 'Services-Misc. Amusement & Recreation6', 'Semiconductors4', 'Medical/Nursing Services5', 'Business Services6', 'Telecommunications Equipment5', 'Integrated oil Companies4', 'Major Banks6', 'Computer Communications Equipment6', 'Major Pharmaceuticals6', 'Major Banks6', 'Major Chemicals4', 'Packaged Foods4', 'Business Services7', 'Property-Casualty Insurers3', 'Major Pharmaceuticals6', 'Computer Software: Prepackaged Software4', 'Life Insurance4', 'Integrated oil Companies6', 'Major Chemicals4', 'Property-Casualty Insurers3', 'Consumer Electronics/Appliances4', 'Metal Fabrications3', 'Property-Casualty Insurers4', 'Biotechnology: Biological Products (No Diagnostic Substances)6', 'Property-Casualty Insurers4', 'Computer peripheral equipment4', 'Integrated oil Companies6', 'Integrated oil Companies5', 'Major Chemicals4', 'Major Chemicals4', 'Major Chemicals4', 'Transportation Services5', 'Transportation Services5', 'Home Furnishings3', 'Transportation Services5', 'Clothing/Shoe/Accessory Stores5', 'Clothing/Shoe/Accessory Stores4', 'Apparel4', 'Computer Software: Programming, Data Processing7', 'Clothing/Shoe/Accessory Stores4', 'Investment Bankers/Brokers/Service5', 'Semiconductors6', 'Other Specialty Stores4', 'EDP Services5', 'Major Pharmaceuticals3', 'Catalog/Specialty Distribution7', 'Investment  ...

# %%
#add the new column to df

sen_df['classification'] = industry_size_data
sen_df.head()
# Out:
#   transaction_date  owner ticker  \
# 2       03/11/2020   Self   ILMN
# 3       03/11/2020   Self   CGNX
# 4       03/11/2020   Self  SIEGY
# 5       02/27/2020  Joint  WCMIX
# 6       02/27/2020  Joint    RPM
#
#                                    asset_description        asset_type  \
# 2                                     Illumina, Inc.             Stock
# 3                                 Cognex Corporation             Stock
# 4                         Siemens Aktiengesellschaft             Stock
# 5  WCM Focused International Growth Fund Institut...  Other Securities
# 6                             RPM International Inc.             Stock
#
#              type              amount  \
# 2     Sale (Full)    $1,001 - $15,000
# 3     Sale (Full)   $15,001 - $50,000
# 4     Sale (Full)   $15,001 - $50,000
# 5        Purchase  $50,001 - $100,000
# 6  Sale (Partial)  $50,001 - $100,000
#
#                                              comment             senator  \
# 2                                                 --  Sheldon Whitehouse
# 3                                                 --  Sheldon Whitehouse
# 4                                                 --  Sheldon Whitehouse
# 5  The filer's portfolio is managed by a third pa...   Daniel S Sullivan
# 6  The filer's portfolio is managed by a third pa...   Daniel S Sullivan
#
#                                             ptr_link  mkt_cap  \
# 2  https://efdsearch.senate.gov/search/view/ptr/4...  $47.15B
# 3  https://efdsearch.senate.gov/search/view/ptr/4...   $8.58B
# 4  https://efdsearch.senate.gov/search/view/ptr/4...     none
# 5  https://efdsearch.senate.gov/search/view/ptr/e...     none
# 6  https://efdsearch.senate.gov/search/view/ptr/e...   $8.74B
#
#              sector                                          industry  \
# 2     Capital Goods  Biotechnology: Laboratory Analytical Instruments
# 3     Capital Goods                   Industrial Machinery/Components
# 4              none                                              none
# 5              none                                              none
# 6  Basic Industries                                   Paints/Coatings
#
#                                       classification
# 2  Biotechnology: Laboratory Analytical Instruments4
# 3                   Industrial Machinery/Components3
# 4                                               none
# 5                                               none
# 6                                   Paints/Coatings3

# %%
#create a list of all the classifications per industry across whole dataframe, to get a view of the breakdown in
#classifications across each industry

classification_industry_breakdown = list()

for x in industry_list:
    y = list()
    for row_tuple in sen_df.itertuples():
        if row_tuple.industry == x:
            y.append(row_tuple.classification)
    classification_industry_breakdown.append(y)
    
print(classification_industry_breakdown[0:9])
# Out:
# [['Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments3', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments3', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments3', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4', 'Biotechnology: Laboratory Analytical Instruments4'], ['Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components4', 'Industrial Machinery/Components6', 'Industrial Machinery/Components4', 'Industrial Machinery/Components6', 'Industrial Machinery/Components5', 'Industrial Machinery/Components5', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components5', 'Industrial Machinery/Components5', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components4', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components5', 'Industrial Machinery/Components4', 'Industrial Machinery/Components4', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components4', 'Industrial Machinery/Components6', 'Industrial Machinery/Components6', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components6', 'Industrial Machinery/Components6', 'Industrial Machinery/Components6', 'Industrial Machinery/Components6', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components4', 'Industrial Machinery/Components6', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machinery/Components3', 'Industrial Machi ...
